# %% [markdown]
# <a href="https://colab.research.google.com/github/lazy-screener/lazy_trader/blob/main/LT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `Welcome to Lazy Trader`
#
# *   automatic Fundamentally strong stocks selction
#
# *   automatic technical analysis , price action and back tested parameters
#
# *   all chart parameters in single plot combining price , volume ,gann level ,qap etc
# *   Detailed chart for index and broder market along probablistic model for  crash prediction
# *   Option chain data also at single place
#
#
#
# *   Best suited for working professional who can't devote much time on analysis
# *   ***The recomendations are for educational purpose only & lazy trader doesn't hold any accountability for your losses......***

# %%
# !pip install numpy
# !pip install -U numpy
import numpy as np

from google.colab import drive
drive.mount('/content/drive')
import sys
path_to_module = '/content/drive/MyDrive/final_pragati'
sys.path.append(path_to_module)
# %run /content/drive/MyDrive/final_pragati/Om_Shrim_Shriye_Namah_02_01_24.ipynb import*

from google.colab import output
output.clear()

# %%
p,p_s,pb,pb_s,d1,d2,d3=get_screener()
print("##################################################################################")
from google.colab import output
output.clear()

# %% [markdown]
# # Below is List of suggested stocks
# # Important Points to consider :
#
#
# 1.   Buy only if GIST displays **"BUY" or "OK-OK" and GIST table is green or yellow** and ***avoid if table looks white or red*** (**if colours not displayed then buy only if sort >135 and Verdict is  "BUY" or "OK-OK**)
# 2.   Three stratgies are quoted as per the traders mindset Positional(lazy) Momentum(Thoda kam Lazy) Longterm (Lazy squared)
# 3.   The Target is genrally 4% for Momentum and 6% for other too
# 4.   These percentage are for busy persons who are only relying on GTT else lazy trader suggested exit poses chances of  better returns ranging from 4-25% (*t&C apply)
# 5.   The score reflects stock's technical and fundamental health
# 6.   % shows the overall health of Index and broder market
# 7.   The lazy trader also will predict major crashes via probablistic model QuadCore
# 8.   The premium memembers later get to know when to go for LUMPSUM in Mutual funds and when to go for SIPs , also to plan a proper exit and cash accumlation also option chain analysis at your finger tips.
#
# 9.   You  are getting everything at one place still Lazy traders are lazy not foolish.
# we are lazy enough to reduce efforts not to eradicatde rational logics.
#
# 10.  lazy trader is not SEBI listed and in any way not responsible for your losses..The recomendations are for educational purpose.
#
# 11.  Jai Hind Jai Bharat

# %%
display_color(d1,d2,d3)
# Out:
# _________________________________________________________________________________
# <style type="text/css">
# #T_1c00e_row0_col1 {
#   background-color: khaki;
# }
# #T_1c00e_row0_col2 {
#   background-color: coral;
# }
# #T_1c00e_row0_col4 {
#   background-color: limegreen;
# }
# #T_1c00e_row0_col6 {
#   background-color: white;
# }
# #T_1c00e_row0_col8 {
#   color: limegreen;
# }
# #T_1c00e_row0_col9 {
#   color: tomato;
# }
# #T_1c00e_row0_col10 {
#   color: green;
# }
# #T_1c00e_row0_col11 {
#   color: red;
# }
# #T_1c00e_row0_col12, #T_1c00e_row0_col13 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1c00e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c00e_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_1c00e_level0_col1" class="col_heading level0 col1" >Strategy</th>
#       <th id="T_1c00e_level0_col2" class="col_heading level0 col2" >Verdict</th>
# ...

# %%
gist(d1,d2,d3)
# Out:
# <style type="text/css">
# #T_ff7b6_row0_col0, #T_ff7b6_row0_col1, #T_ff7b6_row0_col2, #T_ff7b6_row0_col3, #T_ff7b6_row0_col4, #T_ff7b6_row0_col5, #T_ff7b6_row0_col6, #T_ff7b6_row0_col7 {
#   background-color: red;
# }
# </style>
# <table id="T_ff7b6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff7b6_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_ff7b6_level0_col1" class="col_heading level0 col1" >Strategy</th>
#       <th id="T_ff7b6_level0_col2" class="col_heading level0 col2" >Verdict</th>
#       <th id="T_ff7b6_level0_col3" class="col_heading level0 col3" >Date</th>
#       <th id="T_ff7b6_level0_col4" class="col_heading level0 col4" >sort</th>
#       <th id="T_ff7b6_level0_col5" class="col_heading level0 col5" >Beta</th>
#       <th id="T_ff7b6_level0_col6" class="col_heading level0 col6" >Markt_Cap</th>
#       <th id="T_ff7b6_level0_col7" class="col_heading level0 col7" >AD</th>
# ...

# %%
options_data(p)

# %%
# Get Stocks Chart with S&R
get_plot(p,p_s)
get_plot(pb,pb_s)
# Out:
# end date is 2024-01-18
# end date is 2024-01-18

# %%
#name=['TCS.NS',"MCDOWELL-N.NS"]
#get_plot(name,name)
# Out:
# end date is 2024-01-18
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
'''
  #d1.to_csv('/content/drive/MyDrive/screener_data_backup/longterm_LT.csv', mode='w', index=False, header=True)
  #d2.to_csv('/content/drive/MyDrive/screener_data_backup/momentum_LT.csv', mode='w', index=False, header=True)
  #d3.to_csv('/content/drive/MyDrive/screener_data_backup/positional_LT.csv', mode='w', index=False, header=True)
'''
# Out:
# "\n  #d1.to_csv('/content/drive/MyDrive/screener_data_backup/longterm_LT.csv', mode='w', index=False, header=True)\n  #d2.to_csv('/content/drive/MyDrive/screener_data_backup/momentum_LT.csv', mode='w', index=False, header=True)\n  #d3.to_csv('/content/drive/MyDrive/screener_data_backup/positional_LT.csv', mode='w', index=False, header=True)\n"

# %%
'''
  d1.to_csv('/content/drive/MyDrive/screener_data_backup/longterm_LT.csv', mode='a', index=False, header=False)
  d2.to_csv('/content/drive/MyDrive/screener_data_backup/momentum_LT.csv', mode='a', index=False, header=False)
  d3.to_csv('/content/drive/MyDrive/screener_data_backup/positional_LT.csv', mode='a', index=False, header=False)
'''
# Out:
# "\n  d1.to_csv('/content/drive/MyDrive/screener_data_backup/longterm_LT.csv', mode='a', index=False, header=False)\n  d2.to_csv('/content/drive/MyDrive/screener_data_backup/momentum_LT.csv', mode='a', index=False, header=False)\n  d3.to_csv('/content/drive/MyDrive/screener_data_backup/positional_LT.csv', mode='a', index=False, header=False)\n"

# %% [markdown]
# *Previous Trade suggestions will reflect below*

# %%
print("#############################Privious Recent  Trades ###############################")

df = pd.read_csv('/content/drive/MyDrive/screener_data_backup/longterm_LT.csv')
display(df.tail(9))
df = pd.read_csv('/content/drive/MyDrive/screener_data_backup/momentum_LT.csv')
display(df.tail(9))
df_pos = pd.read_csv('/content/drive/MyDrive/screener_data_backup/positional_LT.csv')
display(df_pos.tail(9))
# Out:
# #############################Privious Recent  Trades ###############################
#          Name   Strategy Verdict          %      Score        Date       sort  \
# 0  POLYCAB.NS  LONG TERM    SKIP   8.333333  67.391304  2024-01-16  80.548443
# 1  POLYCAB.NS  LONG TERM    SKIP  33.333333  55.813953  2024-01-17  89.476410
#
#    TG Market_dir MA_150-200   Pos_Candles  Neg_Candles  50_%  75_%  Sector  \
# 0   0    BEARISH       Below        23.93         5.52  14.0  17.0     NaN
# 1   0    BULLISH       Below        35.84         4.74  14.0  17.0     NaN
#
#     Beta  Markt_Cap trend        BSP        AD
# 0  0.662  LARGE CAP  NONE  12.208655  0.013699
# 1  0.662  LARGE CAP  NONE  32.912350  0.011628
#             Name Strategy Verdict          %      Score        Date  \
# 0     DRREDDY.NS    MOM_2   OK-OK  45.454545  54.545455  2024-01-15
# 1    HDFCBANK.NS    MOM_2   OK-OK  45.454545  52.272727  2024-01-15
# 2  IDFCFIRSTB.NS    MOM_2    SKIP  18.181818  70.454545  2024-01-16
# ...

# %% [markdown]
# #*Market Data Below*

# %%
name_plot1=['^NSEI','^CRSLDX',"^IXIC","^GSPC", "^DJI"]
name_plot_s1=['Nifty','Nifty500','NASDAQ','S&P500','DowJones']
get_plot_index(name_plot1,name_plot_s1)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# end date is 2024-01-18
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
name_oc=['NIFTY']
options_data_index(name_oc)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 21456.19921875 NIFTY
# <style type="text/css">
# #T_a6f38_row0_col2, #T_a6f38_row1_col2, #T_a6f38_row2_col2 {
#   background-color: salmon;
# }
# #T_a6f38_row0_col3 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_a6f38_row0_col4, #T_a6f38_row1_col4 {
#   background-color: white;
# }
# #T_a6f38_row1_col3 {
#   background-color: #f67a51;
#   color: #f1f1f1;
# }
# #T_a6f38_row2_col3 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_a6f38_row2_col4 {
#   background-color: lightpink;
# }
# </style>
# <table id="T_a6f38" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6f38_level0_col0" class="col_heading level0 col0" >REMARK</th>
#       <th id="T_a6f38_level0_col1" class="col_heading level0 col1" >NAME</th>
#       <th id="T_a6f38_level0_col2" class="col_heading level0 col2" >strikePrice</th>
# ...

# %%
name_sec =['^CNXIT' ,'^NSEBANK'   ,'^CNXFMCG' ,'^CNXINFRA' ,'^CNXMETAL' ,'^CNXPHARMA' ,'^CNXREALTY' ,'^CNXFIN' ,'^CNXAUTO','^CNXENERGY','^CRSLDX','^CNXCMDT','^CNXMEDIA','^NSMIDCP','^CNXSC','^CRSMID','NIFTYSMLCAP50.NS']
orgname =['IT ' ,'BANK '   ,'FMCG ' ,'INFRA ' ,'METAL ' ,'PHARMA ' ,'REALTY' ,'FINANCE ' ,'AUTO ','ENERGY ','NIFTY 500','COMMODITIES','MEDIA','Nifty Next 50','Small Cap 100','Mid Cap 100','small50']
sector_analysis_onemonth(name_sec,orgname)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...
