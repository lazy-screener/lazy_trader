# %% [markdown]
# <a href="https://colab.research.google.com/github/lazy-screener/lazy_trader/blob/main/MODULAR_PRAGATI_KUBER_om_shirm_update_13_07_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install -U numpy
import numpy as np

from google.colab import drive
drive.mount('/content/drive')
import sys
path_to_module = '/content/drive/MyDrive/final_pragati'
sys.path.append(path_to_module)
# %run /content/drive/MyDrive/final_pragati/Om_Shrim_Shriye_Namah_6_July_23_FundaTechnical_screener_.ipynb import*
#p,p_s,pb,pb_s,d1,d2,d3=get_screener()


# p, p_s for Swing
# pb, pb_s for pullback

from time import sleep
#sleep(0.1) # Time in seconds


# run this first to get screener data       p,p_s=get_screener()
# for sector                get_sector()
# for nifty                 get_nifty()
# for plot                  get_plot(p,p_s)
# for patterns              get_pattern(p)
# for RS OBV RSIDIFF         get_rs(p)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 22.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# ...
# Mounted at /content/drive
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.0 MB/s eta 0:00:00
# ...
# Selecting previously unselected package libta-lib0.
# (Reading database ... 121658 files and directories currently installed.)
# Preparing to unpack libta.deb ...
# Unpacking libta-lib0 (0.4.0-oneiric1) ...
# ...

# %%
#!pip show numpy

# %%
p,p_s,pb,pb_s,d1,d2,d3=get_screener()
print("##################################################################################")

print("#############################Privious POS and LONG ###############################")

df_pos = pd.read_csv('/content/drive/MyDrive/screener_data_backup/positional.csv')
display(df_pos.tail(9))

print("##################################################################################")

df = pd.read_csv('/content/drive/MyDrive/screener_data_backup/longterm.csv')
display(df.tail(9))

print("##################################################################################")
# Out:
# https://www.screener.in/screens/924897/pragati/?page=1
# https://www.screener.in/screens/924897/pragati/?page=2
# https://www.screener.in/screens/924897/pragati/?page=3
# https://www.screener.in/screens/924897/pragati/?page=4
# https://www.screener.in/screens/924897/pragati/?page=5
# https://www.screener.in/screens/926909/nifty100/?page=1
# https://www.screener.in/screens/926909/nifty100/?page=2
# https://www.screener.in/screens/926909/nifty100/?page=3
# https://www.screener.in/screens/926909/nifty100/?page=4
# https://www.screener.in/screens/926909/nifty100/?page=5
# https://www.screener.in/screens/926916/growth_pragati/?page=1
# https://www.screener.in/screens/926916/growth_pragati/?page=2
# https://www.screener.in/screens/926916/growth_pragati/?page=3
# https://www.screener.in/screens/926916/growth_pragati/?page=4
# https://www.screener.in/screens/926916/growth_pragati/?page=5
# https://www.screener.in/screens/420333/mark_minervini/?page=1
# ...

# %%
# !pip install google-auth google-auth-oauthlib google-auth-httplib2

# %%
  d1.to_csv('/content/drive/MyDrive/screener_data_backup/longterm.csv', mode='a', index=False, header=False)
  d2.to_csv('/content/drive/MyDrive/screener_data_backup/momentum.csv', mode='a', index=False, header=False)
  d3.to_csv('/content/drive/MyDrive/screener_data_backup/positional.csv', mode='a', index=False, header=False)

# %%
##################################################################
#updated entry conditions and market derived parameters
# LOOK AFTER 05-07-2023
###################################################################


df_pos = pd.read_csv('/content/drive/MyDrive/screener_data_backup/positional.csv')
display(df_pos.tail(6))
df = pd.read_csv('/content/drive/MyDrive/screener_data_backup/longterm.csv')
display(df.tail(6))
import pandas as pd
import plotly.express as px

# Assuming your DataFrame is named 'df' and 'Date' column is in datetime format
# If 'Date' column is not in datetime format, you can convert it using:
# df['Date'] = pd.to_datetime(df['Date'])

# Group by 'Date' and count occurrences
date_counts1 = df_pos.groupby('Date').size().reset_index(name='Count')
#display(df_pos)
#display(date_counts1.tail(30))
date_counts1=date_counts1.tail(30)
# Plotting the interactive histogram
fig = px.bar(date_counts1, x='Date', y='Count', labels={'Count': 'Count'}, title=' Positional Count  Grouped by Date')
fig.update_xaxes(type='category')  # Ensure correct x-axis ordering
fig.update_layout(xaxis=dict(tickangle=45, tickmode='linear'))
fig.show()


#___________________

# Group by 'Date' and count occurrences
date_counts = df.groupby('Date').size().reset_index(name='Count')
#display(df)
#display(date_counts.tail(30))
date_counts=date_counts.tail(30)
# Plotting the interactive histogram
fig = px.bar(date_counts, x='Date', y='Count', labels={'Count': 'Count'}, title='Longterm Count Grouped by Date')
fig.update_xaxes(type='category')  # Ensure correct x-axis ordering
fig.update_layout(xaxis=dict(tickangle=45, tickmode='linear'))
fig.show()
# Out:
#               Name Strategy Verdict          %      Score        Date  \
# 1081  STYLAMIND.NS   POSI_3    SKIP  37.500000  14.545455  2023-12-12
# 1082     SAFARI.NS   POSI_3    SKIP  29.166667  30.454545  2023-12-12
# 1083    RPGLIFE.NS   POSI_3   OK-OK  37.500000  57.727273  2023-12-19
# 1084  JAMNAAUTO.NS   POSI_3    SKIP  29.166667  23.636364  2023-12-19
# 1085   GILLETTE.NS   POSI_3    SKIP  29.166667  62.272727  2023-12-19
# 1086    SAKSOFT.NS   POSI_3    SKIP  29.166667  66.818182  2023-12-19
#
#             sort  TG Market_dir MA_150-200   Pos_Candles  Neg_Candles  50_%  \
# 1081   62.004812   3    BEARISH       Above        33.31        40.45   6.0
# 1082         NaN   3    BEARISH       Above        33.78        44.08   6.0
# 1083  103.145264   3    BEARISH       Above        31.52        44.27   8.0
# 1084   53.622261   3    BEARISH       Below         0.00        32.72   9.0
# 1085   23.406891   3    BEARISH       Above        12.24        18.20  11.0
# ...

# %%
! pip install nsetools

# %%
a=[]
b=[]
c=[]
display(p)
a=d1["Name"].tolist()
b=d2["Name"].tolist()
c=d3["Name"].tolist()
print(a+b+c)
# Out:
# ['ABBOTINDIA.NS']
# ['ABBOTINDIA.NS', 'ABB.NS', 'BECTORFOOD.NS', 'SBICARD.NS']

# %%
#p,p_s,pb,pb_s,d1,d2,d3=get_screener()

#try to take backup of 15th feb

# %%
push_data(d1,d2,d3)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <!DOCTYPE html>
# 	<html>
# 	  <head>
# 		<meta name="viewport" content="width=device-width, initial-scale=1">
# 		<meta charset="utf-8">
# 		<title>Application Error</title>
# 		<style media="screen">
# 		  html,body,iframe {
# 			margin: 0;
# 			padding: 0;
# 		  }
# 		  html,body {
# 			height: 100%;
# 			overflow: hidden;
# 		  }
# 		  iframe {
# 			width: 100%;
# 			height: 100%;
# 			border: 0;
# 		  }
# 		</style>
# 	  </head>
# 	  <body>
# 		<iframe src="//www.herokucdn.com/error-pages/application-error.html"></iframe>
# 	  </body>
# 	</html>
# [*********************100%%**********************]  1 of 1 completed
# <!DOCTYPE html>
# 	<html>
# 	  <head>
# 		<meta name="viewport" content="width=device-width, initial-scale=1">
# 		<meta charset="utf-8">
# 		<title>Application Error</title>
# 		<style media="screen">
# 		  html,body,iframe {
# 			margin: 0;
# 			padding: 0;
# 		  }
# 		  html,body {
# ...

# %%
#p,p_s=get_screener()
#get_sector()
#get_plot(p,p_s)
#get_pattern(p)
#get_rs(p)

# %%
# NIFTY OBV RSI
get_nifty()

from google.colab import output
from time import sleep
sleep(30)
output.clear()

# %%
# Get Sectorial Plots
get_sector()
from google.colab import output
from time import sleep
#sleep(30)
#output.clear()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ------ ^CNXIT ------
# [*********************100%%**********************]  1 of 1 completed
# ------ ^NSEBANK ------
# [*********************100%%**********************]  1 of 1 completed
# ------ ^CNXFMCG ------
# [*********************100%%**********************]  1 of 1 completed
# ------ ^CNXINFRA ------
# [*********************100%%**********************]  1 of 1 completed
# ------ ^CNXMETAL ------
# [*********************100%%**********************]  1 of 1 completed
# ------ ^CNXPHARMA ------
# [*********************100%%**********************]  1 of 1 completed
# ------ ^CNXREALTY ------
# [*********************100%%**********************]  1 of 1 completed
# ------ ^CNXFIN ------
# [*********************100%%**********************]  1 of 1 completed
# ------ ^CNXAUTO ------
# [*********************100%%**********************]  1 of 1 completed
# ------ ^CNXENERGY ------
# ...

# %%
# Get Stocks Chart with S&R

get_plot(p,p_s)

from google.colab import output
from time import sleep

output.clear()

from IPython.display import clear_output
clear_output()

# %%
# Get Stocks Chart with S&R
get_plot(pb,pb_s)

from google.colab import output
from time import sleep

output.clear()

from IPython.display import clear_output
clear_output()

# %%
# Relative Strengths ,OBV
get_rs(p)
get_rs(pb)
from google.colab import output
from time import sleep
#sleep(50)
#output.clear()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Pattern
get_pattern(p)
get_pattern(pb)
from google.colab import output
from time import sleep
#sleep(30)
#output.clear()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ABBOTINDIA.NS MOM2---------Pos3 21.64 13.33
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-17-f018dec2b7bb> in <cell line: 3>()
#       1 # Pattern
#       2 get_pattern(p)
# ----> 3 get_pattern(pb)
#       4 from google.colab import output
#       5 from time import sleep
#
# <ipython-input-1-740de2d11dae> in get_pattern(name_plot)
#     248       cprint(df['new_mom'][-1].round(2), 'red', attrs=['bold'],end=' ')
#     249       cprint(df['new_pos'][-1].round(2), 'red', attrs=['bold'])
# --> 250   return pos,mom
#
# UnboundLocalError: local variable 'pos' referenced before assignment
